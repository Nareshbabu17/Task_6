# %%
import pandas as pd
import numpy as np

# %%
th_1 = pd.read_csv('takehome_users.csv')

# %%
th_1
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Tha�s
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
th_1['creation_time'] = pd.to_datetime(th_1.creation_time)

# %%
th_1.dtypes
# Out:
# object_id                              int64
# creation_time                 datetime64[ns]
# name                                  object
# email                                 object
# creation_source                       object
# last_session_creation_time           float64
# opted_in_to_mailing_list               int64
# enabled_for_marketing_drip             int64
# org_id                                 int64
# invited_by_user_id                   float64
# dtype: object

# %%
th_1
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12         Lima Tha�s
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
th_1['name'].value_counts()
# Out:
# Araujo Gabriela      5
# Cavalcanti Victor    5
# Costa Alice          4
# Cunha Melissa        4
# Correia Leonardo     4
#                     ..
# Ifould Noah          1
# Sousa Jo�o           1
# Wright Linda         1
# West Logan           1
# Cumpston Amy         1
# Name: name, Length: 11349, dtype: int64

# %%
th_1
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12         Lima Tha�s
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
th_1.sort_values(by='creation_time',inplace = True)

# %%
pd.date_range(start=th_1.creation_time(2012,5,31),end=th_1.creation_time(2015,6,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-9db063dced59> in <module>
# ----> 1 pd.date_range(start=th_1.creation_time(2012,5,31),end=th_1.creation_time(2015,6,6))
#
# TypeError: 'Series' object is not callable

# %%
th_1['Week/Year'] = th_1['creation_time'].apply(lambda x: "%d/%d" % (x.week, x.year))

# %%
th_1
# Out:
#        object_id       creation_time                 name  \
# 3860        3861 2012-05-31 00:43:27         Jensen Stine
# 11429      11430 2012-05-31 01:42:31            Wood Levi
# 7169        7170 2012-05-31 06:23:51  Cavalcanti Leonardo
# 10011      10012 2012-05-31 08:20:06       Spikes Danille
# 11998      11999 2012-05-31 11:55:59         Faber Annett
# ...          ...                 ...                  ...
# 6944        6945 2014-05-30 23:10:35     Sandoval Matthew
# 9687        9688 2014-05-30 23:12:01           Coveny Taj
# 10163      10164 2014-05-30 23:27:30            Walsh Sam
# 3489        3490 2014-05-30 23:45:01     Oliveira Estevan
# 6052        6053 2014-05-30 23:59:19   Armbruster Kandace
#
#                                        email    creation_source  \
# 3860                  StineAJensen@yahoo.com         ORG_INVITE
# 11429                   LeviWood@hotmail.com         ORG_INVITE
# 7169   LeonardoPereiraCavalcanti@hotmail.com         ORG_INVITE
# ...

# %%
th_1.groupby(['Week/Year', 'name']).size()
# Out:
# Week/Year  name
# 1/2012     Baier Philipp       1
#            Beirne Hannah       1
#            Clausen Anders      1
#            Cottrell Charles    1
#            Gomes Beatrice      1
#                               ..
# 9/2014     Villadsen Julie     1
#            Whittle Ricardo     1
#            Williams Josh       1
#            Wunder Camille      1
#            Yabsley Cooper      1
# Length: 11996, dtype: int64

# %%
th_2 = pd.read_csv('takehome_user_engagement.csv')

# %%
th_2
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]
